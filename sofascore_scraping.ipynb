# %%
import requests

headers = {
    'accept': '*/*',
    'accept-language': 'it-IT,it;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    # 'cookie': '_ga=GA1.1.619664759.1717993444; FCCDCF=%5Bnull%2Cnull%2Cnull%2C%5B%22CP__pQAP__pQAEsACBITA4EoAP_.dnAACAgAAAA%22%2C%222~70.89.108.149.211.313.358.415.486.540.621.981.1029.1046.1092.1097.1126.1205.1301.1516.1558.1584.1598.1651.1697.1716.1753.1810.1832.1985.2328.2373.2440.2571.2572.2575.2577.2628.2642.2677.2767.2860.2878.2887.2922.3182.3190.3234.3290.3292.3331.10631~dv.%22%2C%22702A03C4-78EA-4B57-9557-202E17B9C5AA%22%5D%5D; _ga_QH2YGS7BB4=GS1.1.1718004187.5.1.1718004187.0.0.0; _ga_3KF4XTPHC4=GS1.1.1718004187.5.1.1718004187.60.0.0; _lr_env_src_ats=false; __browsiUID=c364b98e-7fa1-4f7d-8ee2-a2682a5f95e4; __qca=P0-387479165-1728812756527; pbjs-unifiedid=%7B%22TDID_LOOKUP%22%3A%22FALSE%22%2C%22TDID_CREATED_AT%22%3A%222024-10-13T09%3A46%3A36%22%7D; pbjs-unifiedid_cst=yyzLLLEsNg%3D%3D; _lr_retry_request=true; gcid_first=93d9b10a-1887-40ff-8249-3d4ee481ad30; __browsiSessionID=56a3e92f-16b4-46b3-baee-490dd2c9d1cb&true&DEFAULT&it&desktop-4.32.498&false; __gads=ID=ffe02b1d6f3e3473:T=1717993474:RT=1729344064:S=ALNI_MaPoIAQzJBvzF6fNmtghJBNJ0eEIg; __gpi=UID=00000e5449384083:T=1717993474:RT=1729344064:S=ALNI_Ma4PwWdDuw3GQwmomh7Czfsy9gx_g; __eoi=ID=1ce104469e22535e:T=1717993474:RT=1729344064:S=AA-AfjaTx8mfdnogX3bG85rkydlf; FCNEC=%5B%5B%22AKsRol-C0uRApym2sffx84MXZUPW5F_BCvw9dZdahfWlrOZgMIcR092_v1w7r7pvEwPakws4feiRzn7AZ9OcuXgEReLs875v3YgURH1xDEZE2PvANDKIgsYF2oNyDz5KkuN2ejlLb_u0o3fXdjKGqh0WpL94jbT0qw%3D%3D%22%5D%5D; _ga_HNQ9P9MGZR=GS1.1.1729337934.8.1.1729344226.18.0.0',
    'if-none-match': 'W/"0ab4227779"',
    'priority': 'u=1, i',
    'referer': 'https://www.sofascore.com/it/torneo/calcio/italy/serie-a/23',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
    'x-requested-with': '633fde',
}

# %%
response = requests.get(
    'https://www.sofascore.com/api/v1/unique-tournament/23/season/37475/events/round/1',
    headers=headers,
)
response
# Out:
# <Response [200]>

# %%
matches = response.json()
events =matches['events']
len(events)
# Out:
# 10

# %%
events[0].keys()
# Out:
# dict_keys(['tournament', 'season', 'roundInfo', 'customId', 'status', 'winnerCode', 'homeTeam', 'awayTeam', 'homeScore', 'awayScore', 'coverage', 'time', 'changes', 'hasGlobalHighlights', 'hasEventPlayerStatistics', 'hasEventPlayerHeatMap', 'detailId', 'crowdsourcingDataDisplayEnabled', 'id', 'homeRedCards', 'startTimestamp', 'slug', 'finalResultOnly', 'feedLocked', 'isEditor'])

# %%
id
# Out:
# 9644905

# %%
id = events[0]['id']
response = requests.get(f'https://www.sofascore.com/api/v1/event/{id}/statistics', headers=headers)
statistics = response.json()
all =statistics['statistics'][0]['groups']

# %%
print(all[0].keys())
for x in all:
    print(x['groupName'])
# Out:
# dict_keys(['groupName', 'statisticsItems'])
# Match overview
# Shots
# Attack
# Passes
# Duels
# Defending
# Goalkeeping
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
events[0]
# Out:
# {'tournament': {'name': 'Serie A',
#   'slug': 'serie-a',
#   'category': {'name': 'Italy',
#    'slug': 'italy',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 31,
#    'flag': 'italy',
#    'alpha2': 'IT'},
#   'uniqueTournament': {'name': 'Serie A',
#    'slug': 'serie-a',
#    'primaryColorHex': '#09519e',
#    'secondaryColorHex': '#008fd7',
#    'category': {'name': 'Italy',
#     'slug': 'italy',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 31,
#     'flag': 'italy',
#     'alpha2': 'IT'},
#    'userCount': 1015219,
#    'hasPerformanceGraphFeature': False,
#    'id': 23,
#    'hasEventPlayerStatistics': False,
#    'displayInverseHomeAwayTeams': False},
#   'priority': 609,
#   'isGroup': True,
#   'isLive': True,
#   'id': 33},
#  'season': {'name': 'Serie A 21/22',
#   'year': '21/22',
#   'editor': True,
#   'id': 37475},
#  'roundInfo': {'round': 1},
#  'customId': 'eebsTfb',
# ...
