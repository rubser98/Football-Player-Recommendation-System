# %%
import os 
import pandas as pd

# %%
statsbomb_path = 'Dataset\Statsbomb\data'
df_comps = pd.read_json(os.path.join(statsbomb_path,'competitions.json'))
df_comps.head()
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-05-21T03:36:44.090970  2024-05-21T03:38:27.534702
# ...

# %%
seasons = list(df_comps.season_name.unique())
selected_seasons = sorted(seasons, reverse = True)[:8]
selected_seasons = [x for x in selected_seasons if '/' in x]
selected_seasons
# Out:
# ['2023/2024', '2022/2023', '2021/2022', '2020/2021', '2019/2020']

# %%
df_comps[df_comps['season_name'].isin(selected_seasons)]
# Out:
#     competition_id  season_id country_name         competition_name  \
# 0                9        281      Germany            1. Bundesliga
# 24              37         90      England  FA Women's Super League
# 25              37         42      England  FA Women's Super League
# 36            1238        108        India      Indian Super league
# 37              11         90        Spain                  La Liga
# 38              11         42        Spain                  La Liga
# 57               7        235       France                  Ligue 1
# 58               7        108       France                  Ligue 1
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 24             female              False                      False
# 25             female              False                      False
# 36               male              False                      False
# ...

# %%
df_comps.competition_name.unique()
# Out:
# array(['1. Bundesliga', 'African Cup of Nations', 'Champions League',
#        'Copa del Rey', "FA Women's Super League", 'FIFA U20 World Cup',
#        'FIFA World Cup', 'Indian Super league', 'La Liga',
#        'Liga Profesional', 'Ligue 1', 'Major League Soccer',
#        'North American League', 'NWSL', 'Premier League', 'Serie A',
#        'UEFA Euro', 'UEFA Europa League', "UEFA Women's Euro",
#        "Women's World Cup"], dtype=object)

# %%
df_comps[df_comps.competition_name == 'Serie A']
# Out:
#     competition_id  season_id country_name competition_name  \
# 65              12         27        Italy          Serie A
# 66              12         86        Italy          Serie A
#
#    competition_gender  competition_youth  competition_international  \
# 65               male              False                      False
# 66               male              False                      False
#
#    season_name               match_updated match_updated_360  \
# 65   2015/2016  2024-03-10T16:14:00.166197              None
# 66   1986/1987  2023-06-18T01:55:53.343752              None
#
#    match_available_360             match_available
# 65                None  2024-03-10T16:14:00.166197
# 66                None  2023-06-18T01:55:53.343752

# %%
# !pip install translate
# Out:
# ...
#                                               0.0/3.8 MB ? eta -:--:--
#      ---                                      0.3/3.8 MB 8.9 MB/s eta 0:00:01
#      -----------------                        1.7/3.8 MB 26.7 MB/s eta 0:00:01
#      -----------------------------            2.8/3.8 MB 22.0 MB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 24.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.1.2 -> 24.1
# [notice] To update, run: C:\Users\nosen\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from translate import Translator

translator = Translator(to_lang="en")
translation = translator.translate("Ciao mondo")
print(translation)
# Out:
# Ciao mondo

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#                                               0.0/55.1 kB ? eta -:--:--
#      ---------------------------------------- 55.1/55.1 kB 2.8 MB/s eta 0:00:00
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      -----------------                        0.5/1.2 MB 15.9 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 18.3 MB/s eta 0:00:00
# ...
#                                               0.0/133.4 kB ? eta -:--:--
#      ---------------------------------------- 133.4/133.4 kB ? eta 0:00:00
# ...
#                                               0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB ? eta 0:00:00
# ...
#                                               0.0/42.6 kB ? eta -:--:--
#      ---------------------------------------- 42.6/42.6 kB ? eta 0:00:00
# ...

# %%
from googletrans import Translator

translator = Translator()
translated = translator.translate('Dal Castellani è tutto, buon proseguimento di serata. Alla prossima.', src='it', dest='en')
print(translated.text)
# Out:
# From Castellani is everything, good continuation of the evening.Until next time.

# %%
+
